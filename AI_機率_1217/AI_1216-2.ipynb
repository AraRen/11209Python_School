# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder="\AI_機率_1217"

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (2.1.4)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jacky\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\users\jacky\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.26.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.3.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (3.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\jacky\appdata\roaming\python\python310\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.46.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jacky\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=8 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\jacky\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.26.2)
# Requirement already satisfied: six>=1.5 in c:\users\jacky\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import LabelEncoder

# %%
# 讀取資料
data = pd.read_csv('\GitHub\AI_機率_1217\data2.csv')  # 請替換成您的資料檔案名稱或路徑

# %%
# 將站點名稱轉換成數字特徵 (使用 Label Encoding)
label_encoder = LabelEncoder()
data['站點名稱'] = label_encoder.fit_transform(data['站點名稱'])

# %%
data
# Out:
#      站點名稱  可還
# 0       2  13
# 1       0  16
# 2       4  17
# 3       1  34
# 4       3   6
# ..    ...  ..
# 475     2  13
# 476     0  17
# 477     4  17
# 478     1  36
# 479     3   9
#
# [480 rows x 2 columns]

# %%
# 將資料分為特徵值和目標值
X = data.drop('可還', axis=1)
y = data['可還']

# %%
# 初始化決策樹回歸模型
model = DecisionTreeRegressor(random_state=42)

# %%
# 訓練決策樹模型
model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
# 預測5個站點的可還車輛數機率
site_1 = label_encoder.transform(['E2'])  # 請替換成站點名稱
site_2 = label_encoder.transform(['E3'])  # 請替換成站點名稱
site_3 = label_encoder.transform(['E4'])  # 請替換成站點名稱
site_4 = label_encoder.transform(['E5'])  # 請替換成站點名稱
site_5 = label_encoder.transform(['E6'])  # 請替換成站點名稱

probabilities = model.predict([site_1, site_2, site_3, site_4, site_5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 # 預測5個站點的可還車輛數機率
# ----> 2 site_1 = label_encoder.transform(['E2'])  # 請替換成站點名稱
#       3 site_2 = label_encoder.transform(['E3'])  # 請替換成站點名稱
#       4 site_3 = label_encoder.transform(['E4'])  # 請替換成站點名稱
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\preprocessing\_label.py:132, in LabelEncoder.transform(self, y)
#     119 """Transform labels to normalized encoding.
#     120
#     121 Parameters
#    (...)
#     129     Labels as normalized encodings.
#     130 """
#     131 check_is_fitted(self)
# --> 132 y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#     133 # transform of empty array is empty array
#     134 if _num_samples(y) == 0:
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1219, in column_or_1d(y, dtype, warn)
#    1193 """Ravel column or 1d numpy array, else raises an error.
#    1194
#    1195 Parameters
#    (...)
#    1216     If `y` is not a 1D array or a 2D array with a single row or column.
#    1217 """
#    1218 xp, _ = get_namespace(y)
# -> 1219 y = check_array(
#    1220     y,
#    1221     ensure_2d=False,
#    1222     dtype=dtype,
#    1223     input_name="y",
#    1224     force_all_finite=False,
#    1225     ensure_min_samples=0,
#    1226 )
#    1228 shape = y.shape
#    1229 if len(shape) == 1:
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:913, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     905     if xp.isdtype(array.dtype, ("real floating", "complex floating")):
#     906         _assert_all_finite(
#     907             array,
#     908             allow_nan=False,
#    (...)
#     911             input_name=input_name,
#     912         )
# --> 913     array = xp.astype(array, dtype, copy=False)
#     914 else:
#     915     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#
# File c:\Users\jacky\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\_array_api.py:245, in _NumPyAPIWrapper.astype(self, x, dtype, copy, casting)
#     243 def astype(self, x, dtype, *, copy=True, casting="unsafe"):
#     244     # astype is not defined in the top level NumPy namespace
# --> 245     return x.astype(dtype, copy=copy, casting=casting)
#
# ValueError: invalid literal for int() with base 10: 'E2'

# %%
# 獲取機率最高的站點
best_site_index = probabilities.argmax()
best_site_name = label_encoder.inverse_transform([best_site_index])[0]

print(f"預測站點1的可還車輛數機率：{probabilities[0]}")
print(f"預測站點2的可還車輛數機率：{probabilities[1]}")
print(f"預測站點3的可還車輛數機率：{probabilities[2]}")
print(f"預測站點4的可還車輛數機率：{probabilities[3]}")
print(f"預測站點5的可還車輛數機率：{probabilities[4]}")
print(f"最佳選擇的可還站點：{best_site_name}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # 獲取機率最高的站點
# ----> 2 best_site_index = probabilities.argmax()
#       3 best_site_name = label_encoder.inverse_transform([best_site_index])[0]
#       5 print(f"預測站點1的可還車輛數機率：{probabilities[0]}")
#
# NameError: name 'probabilities' is not defined

# %%
# 繪製機率圖
import matplotlib.pyplot as plt
sites = ['E2', 'E3', 'E4', 'E5', 'E6']
plt.bar(sites, probabilities, color='skyblue')
plt.xlabel('Station')  # 站點
plt.ylabel('Predict the Probability of returned') # 預測可還車輛數機率
plt.title('Predict the Probablity of returned') # 5個站點可還車輛數機率預測
plt.ylim(0, 40)  # 調整 y 軸範圍
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       2 import matplotlib.pyplot as plt
#       3 sites = ['E2', 'E3', 'E4', 'E5', 'E6']
# ----> 4 plt.bar(sites, probabilities, color='skyblue')
#       5 plt.xlabel('Station')  # 站點
#       6 plt.ylabel('Predict the Probability of returned') # 預測可還車輛數機率
#
# NameError: name 'probabilities' is not defined
